# %% [markdown]
# <a href="https://colab.research.google.com/github/pennuel/Ai-Object-detector-and-translator-APP/blob/master/Using_llama_index_and_PaLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q llama-index
# !pip install pypdf
# !pip install google-generativeai
# !pip install transformers

# %% [markdown]
# #Step 2: install using the required libraries

# %%
from llama_index import SimpleDirectoryReader, VectorStoreIndex
from llama_index.llms.palm import PaLM
from IPython.display import Markdown, display
from llama_index import ServiceContext
from llama_index import StorageContext, load_index_from_storage
import os

# %% [markdown]
# #Step 3: load the pdf files and extract the data from the PDF Files

# %%
# !mkdir data

# %%
documents = SimpleDirectoryReader('data').load_data()

# %%
print(documents)

# %% [markdown]
# #Step 4: Split the text into small Chunks and create embeddings for each of the text chunks

# %%
os.environ['GOOGLE_API_KEY'] = 'AIzaSyCNTMwPghDPKkAvTfJmYSo2jzDr8VUpn5U'

# %%
llm = PaLM()

# %%
# Configure Service Context
service_context = ServiceContext.from_defaults(llm=llm, chunk_size=800, chunk_overlap=20)
# Out:
# ******
# Could not load OpenAIEmbedding. Using HuggingFaceBgeEmbeddings with model_name=BAAI/bge-small-en. If you intended to use OpenAI, please check your OPENAI_API_KEY.
# Original error:
# No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
# ******
# ...
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
index = VectorStoreIndex.from_documents(documents, service_context=service_context)

# %% [markdown]
# #Step 5: Storing and loading the index

# %%
index.storage_context.persist()

# %%
#Loading the index
# storage_context = StorageContext.from_defaults(persist_dir = './storage')
# index = load_index_from_storage(storage_context=storage_context)

# %% [markdown]
# #Step 6: Querying the Database

# %%
query_engine = index.as_query_engine()
response = query_engine.query("explain to me chapter 2")
display(Markdown(f"{response}"))
# Out:
# Chapter 2 is about Alexis's life. She struggled to learn English when she first moved to America. Her classmates criticized her for being a slow learner.

# %%
# Out:
# use your finger while reading
